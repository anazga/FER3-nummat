# %% [markdown]
# # Numerička matematika - 22. predavanje

# %% [markdown]
# ## 1. Uvod u numeričku optimizaciju

# %% [markdown]
# U sljedećem predavanju opisujemo neke od metoda bezuvjetne optimizacije u koje spadaju i metoda najbržeg silaska kao i kvazi Newtonove metode.

# %%
from IPython.lib.display import YouTubeVideo
vid = YouTubeVideo("olZJ-j4XGPU")
display(vid)

# %% [markdown]
# Sada proučite [link](https://docs.scipy.org/doc/scipy/reference/optimize.html#module-scipy.optimize)
